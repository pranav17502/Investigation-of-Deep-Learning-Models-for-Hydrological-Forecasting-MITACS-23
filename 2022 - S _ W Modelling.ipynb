# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Summer

# %% [markdown]
# ## **Importing Data from 2018-2020**

# %%
river_2018 = pd.read_csv("RiverFlow2022Summer.csv")

# %%
river_2018
# Out:
#                 Timestamp  BlairCreek  Bridgeport  BridgeportWQ       Doon  \
# 0     2022-04-01 00:00:00    0.399833   27.165000      8.563393  25.075981
# 1     2022-04-01 01:00:00    0.398375   27.690000      8.859566  25.244563
# 2     2022-04-01 02:00:00    0.400667   28.346250      9.199617  25.438430
# 3     2022-04-01 03:00:00    0.394000   29.221250      9.701020  25.747197
# 4     2022-04-01 04:00:00    0.394000   30.648000     10.621429  26.068777
# ...                   ...         ...         ...           ...        ...
# 4387  2022-09-30 19:00:00    0.168583   12.534125     12.075000  10.748998
# 4388  2022-09-30 20:00:00    0.172750   12.507625     12.061503  10.796102
# 4389  2022-09-30 21:00:00    0.170563   12.395000     12.007653  10.835214
# 4390  2022-09-30 22:00:00    0.172437   12.335375     11.957143  10.839883
# 4391  2022-09-30 23:00:00    0.173063   12.255875     11.861735  10.806474
#
#         Drayton  Elmira  Erbsville     Keldon   Leggatt  MillCreek  \
# 0     16.196284   1.463   0.400253  10.590625  8.151722   1.271078
# 1     17.772941   1.456   0.407559  10.834375  8.530825   1.284089
# 2     18.732680   1.449   0.412387  10.839583  8.971262   1.293902
# 3     19.130285   1.435   0.415971  10.669792  9.458245   1.300416
# 4     18.988939   1.428   0.416322  10.384375  9.984595   1.302603
# ...         ...     ...        ...        ...       ...        ...
# 4387   0.380693   0.365   0.065536   0.107948  0.509200   0.266934
# 4388   0.377477   0.365   0.064706   0.107078  0.508080   0.266000
# 4389   0.375035   0.360   0.064075   0.106050  0.505233   0.265175
# 4390   0.372786   0.360   0.064125   0.104469  0.503600   0.264066
# 4391   0.371872   0.360   0.063673   0.103283  0.502060   0.263391
#
#       Moorefield  Phillipsburg     Road32  VictoriaRoad   Waldemar  \
# 0       6.234535      9.233125  10.187767      1.915917  16.142382
# 1       6.158276     10.743200  10.052696      1.934546  16.861028
# 2       6.047145     12.401600   9.924733      1.952998  17.613924
# 3       5.921047     14.110400   9.844164      1.976338  18.546916
# 4       5.786531     15.656125   9.813358      1.998780  19.556823
# ...          ...           ...        ...           ...        ...
# 4387    0.041602      0.303750   2.285948      1.087961   0.769935
# 4388    0.042135      0.300000   2.311057      1.088530   0.774982
# 4389    0.043083      0.297250   2.342896      1.089673   0.769077
# 4390    0.043638      0.296500   2.366162      1.089130   0.767120
# 4391    0.044428      0.294500   2.366162      1.087607   0.764751
#
#       WillowBrook       York
# 0        3.418000  75.750000
# 1        3.544000  74.836893
# 2        3.676000  74.627184
# 3        3.814000  74.603883
# 4        3.955000  74.440777
# ...           ...        ...
# 4387     0.028117  21.462500
# 4388     0.027993  21.565761
# 4389     0.027670  21.679348
# 4390     0.027600  21.797826
# 4391     0.027580  21.797826
#
# [4392 rows x 18 columns]

# %%
river_2018.set_index(["Timestamp"], inplace= True)

# %%
river_2018[river_2018 == np.nan].count()
# Out:
# BlairCreek      0
# Bridgeport      0
# BridgeportWQ    0
# Doon            0
# Drayton         0
# Elmira          0
# Erbsville       0
# Keldon          0
# Leggatt         0
# MillCreek       0
# Moorefield      0
# Phillipsburg    0
# Road32          0
# VictoriaRoad    0
# Waldemar        0
# WillowBrook     0
# York            0
# dtype: int64

# %%
river_2018[river_2018 <= 0].count()
# Out:
# BlairCreek      0
# Bridgeport      0
# BridgeportWQ    0
# Doon            0
# Drayton         0
# Elmira          0
# Erbsville       0
# Keldon          0
# Leggatt         0
# MillCreek       0
# Moorefield      0
# Phillipsburg    0
# Road32          0
# VictoriaRoad    0
# Waldemar        0
# WillowBrook     0
# York            0
# dtype: int64

# %% [markdown]
# ## **Preprocessing of DataFrame**

# %% [markdown]
# We need only York, Doon and Bridgeport Stations data

# %% [markdown]
# Extracting only the three stations we which we need

# %%
river_2018 = river_2018[["York", "Doon", "Bridgeport"]]
river_2018
# Out:
#                           York       Doon  Bridgeport
# Timestamp
# 2022-04-01 00:00:00  75.750000  25.075981   27.165000
# 2022-04-01 01:00:00  74.836893  25.244563   27.690000
# 2022-04-01 02:00:00  74.627184  25.438430   28.346250
# 2022-04-01 03:00:00  74.603883  25.747197   29.221250
# 2022-04-01 04:00:00  74.440777  26.068777   30.648000
# ...                        ...        ...         ...
# 2022-09-30 19:00:00  21.462500  10.748998   12.534125
# 2022-09-30 20:00:00  21.565761  10.796102   12.507625
# 2022-09-30 21:00:00  21.679348  10.835214   12.395000
# 2022-09-30 22:00:00  21.797826  10.839883   12.335375
# 2022-09-30 23:00:00  21.797826  10.806474   12.255875
#
# [4392 rows x 3 columns]

# %%
len(river_2018)
# Out:
# 4392

# %% [markdown]
# Here, I will divide the dataframe into training and testing by 70-30 split in chronological order. So training would contain - 3075 and testing would contain the rest.

# %%
train_2018 = river_2018.iloc[0: 3075, :]
train_2018
# Out:
#                           York       Doon  Bridgeport
# Timestamp
# 2022-04-01 00:00:00  75.750000  25.075981    27.16500
# 2022-04-01 01:00:00  74.836893  25.244563    27.69000
# 2022-04-01 02:00:00  74.627184  25.438430    28.34625
# 2022-04-01 03:00:00  74.603883  25.747197    29.22125
# 2022-04-01 04:00:00  74.440777  26.068777    30.64800
# ...                        ...        ...         ...
# 2022-08-06 22:00:00  23.363043  10.229119    11.18200
# 2022-08-06 23:00:00  23.363043  10.538244    11.11600
# 2022-08-07 00:00:00  23.338587  10.415840    11.09400
# 2022-08-07 01:00:00  22.971739  10.077738    11.06100
# 2022-08-07 02:00:00  22.555978  10.009994    11.06650
#
# [3075 rows x 3 columns]

# %%
test_2018 = river_2018.iloc[3075: , :]
test_2018
# Out:
#                           York       Doon  Bridgeport
# Timestamp
# 2022-08-07 03:00:00  22.164674   9.989801   11.083000
# 2022-08-07 04:00:00  21.810054   9.938941   11.083000
# 2022-08-07 05:00:00  21.565761   9.894328   11.088500
# 2022-08-07 06:00:00  21.390217   9.883953   11.099500
# 2022-08-07 07:00:00  21.235326   9.881656   11.061000
# ...                        ...        ...         ...
# 2022-09-30 19:00:00  21.462500  10.748998   12.534125
# 2022-09-30 20:00:00  21.565761  10.796102   12.507625
# 2022-09-30 21:00:00  21.679348  10.835214   12.395000
# 2022-09-30 22:00:00  21.797826  10.839883   12.335375
# 2022-09-30 23:00:00  21.797826  10.806474   12.255875
#
# [1317 rows x 3 columns]

# %% [markdown]
# Now, we need to use windowing.

# %%
train_df = pd.concat([train_2018["York"], train_2018["Doon"].shift(-18), train_2018["Bridgeport"].shift(-24)], axis= 1)
train_df
# Out:
#                           York       Doon  Bridgeport
# Timestamp
# 2022-04-01 00:00:00  75.750000  33.050738      32.016
# 2022-04-01 01:00:00  74.836893  33.118278      31.674
# 2022-04-01 02:00:00  74.627184  33.380929      31.314
# 2022-04-01 03:00:00  74.603883  33.236389      30.927
# 2022-04-01 04:00:00  74.440777  32.928007      30.549
# ...                        ...        ...         ...
# 2022-08-06 22:00:00  23.363043        NaN         NaN
# 2022-08-06 23:00:00  23.363043        NaN         NaN
# 2022-08-07 00:00:00  23.338587        NaN         NaN
# 2022-08-07 01:00:00  22.971739        NaN         NaN
# 2022-08-07 02:00:00  22.555978        NaN         NaN
#
# [3075 rows x 3 columns]

# %%
test_df = pd.concat([test_2018["York"], test_2018["Doon"].shift(-18), test_2018["Bridgeport"].shift(-24)], axis= 1)
test_df
# Out:
#                           York      Doon  Bridgeport
# Timestamp
# 2022-08-07 03:00:00  22.164674  9.505371   11.193000
# 2022-08-07 04:00:00  21.810054  9.559629   11.369000
# 2022-08-07 05:00:00  21.565761  9.609380   11.501000
# 2022-08-07 06:00:00  21.390217  9.665013   11.567000
# 2022-08-07 07:00:00  21.235326  9.674651   11.686125
# ...                        ...       ...         ...
# 2022-09-30 19:00:00  21.462500       NaN         NaN
# 2022-09-30 20:00:00  21.565761       NaN         NaN
# 2022-09-30 21:00:00  21.679348       NaN         NaN
# 2022-09-30 22:00:00  21.797826       NaN         NaN
# 2022-09-30 23:00:00  21.797826       NaN         NaN
#
# [1317 rows x 3 columns]

# %%
train_df.head(25)
# Out:
#                           York       Doon  Bridgeport
# Timestamp
# 2022-04-01 00:00:00  75.750000  33.050738    32.01600
# 2022-04-01 01:00:00  74.836893  33.118278    31.67400
# 2022-04-01 02:00:00  74.627184  33.380929    31.31400
# 2022-04-01 03:00:00  74.603883  33.236389    30.92700
# 2022-04-01 04:00:00  74.440777  32.928007    30.54900
# 2022-04-01 05:00:00  74.440777  33.025838    30.36900
# 2022-04-01 06:00:00  74.440777  32.537980    32.15100
# 2022-04-01 07:00:00  74.440777  32.129635    36.03900
# 2022-04-01 08:00:00  74.440777  31.806579    37.86300
# 2022-04-01 09:00:00  74.440777  31.316405    38.96475
# 2022-04-01 10:00:00  74.440777  30.886638    39.75450
# 2022-04-01 11:00:00  74.440777  30.444695    39.96900
# 2022-04-01 12:00:00  74.440777  29.995052    39.86175
# 2022-04-01 13:00:00  74.440777  29.797059    39.72525
# 2022-04-01 14:00:00  74.464078  29.213674    39.75450
# 2022-04-01 15:00:00  74.953398  29.023503    39.59850
# 2022-04-01 16:00:00  76.187500  30.144813    39.55950
# 2022-04-01 17:00:00  76.875000  33.127353    39.44250
# 2022-08-06 11:00:00  25.441848        NaN         NaN
# 2022-08-06 12:00:00  25.319565        NaN         NaN
# 2022-08-06 13:00:00  25.062772        NaN         NaN
# 2022-08-06 14:00:00  24.989402        NaN         NaN
# 2022-08-06 15:00:00  24.879348        NaN         NaN
# 2022-08-06 16:00:00  24.536957        NaN         NaN
# 2022-08-06 17:00:00  24.304620        NaN         NaN
# 2022-08-06 18:00:00  24.011141        NaN         NaN
# 2022-08-06 19:00:00  23.644293        NaN         NaN
# 2022-08-06 20:00:00  23.424185        NaN         NaN
# 2022-08-06 21:00:00  23.363043        NaN         NaN
# 2022-08-06 22:00:00  23.363043        NaN         NaN
# 2022-08-06 23:00:00  23.363043        NaN         NaN
# 2022-08-07 00:00:00  23.338587        NaN         NaN
# 2022-08-07 01:00:00  22.971739        NaN         NaN
# 2022-08-07 02:00:00  22.555978        NaN         NaN

# %% [markdown]
# We can see that there are 18 missing in Doon and 24 missing in Bridgeport. Now we will drop na values, so total number of rows would decrease by 24.

# %%
train_df.shape, test_df.shape
# Out:
# ((3075, 3), (1317, 3))

# %%
train_df.dropna(inplace= True)
train_df.shape
# Out:
# (3051, 3)

# %%
test_df.dropna(inplace= True)
test_df.shape
# Out:
# (1293, 3)

# %% [markdown]
# We can see that there is a decrease of 24 rows after dropping the na values. So far everything is correct.

# %% [markdown]
# ## **Features and Target extraction with Scaling**

# %%
train_df.head()
# Out:
#                           York       Doon  Bridgeport
# Timestamp
# 2022-04-01 00:00:00  75.750000  33.050738      32.016
# 2022-04-01 01:00:00  74.836893  33.118278      31.674
# 2022-04-01 02:00:00  74.627184  33.380929      31.314
# 2022-04-01 03:00:00  74.603883  33.236389      30.927
# 2022-04-01 04:00:00  74.440777  32.928007      30.549

# %%
train_df.tail()
# Out:
#                           York       Doon  Bridgeport
# Timestamp
# 2022-08-05 22:00:00  26.532222  10.156592     11.1820
# 2022-08-05 23:00:00  26.994444  10.073517     11.1160
# 2022-08-06 00:00:00  27.225556  10.023583     11.0940
# 2022-08-06 01:00:00  27.240000  10.009535     11.0610
# 2022-08-06 02:00:00  27.240000  10.032394     11.0665

# %% [markdown]
# ### Features

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scalerFeature = MinMaxScaler()

# %%
features = scalerFeature.fit_transform(train_df)

# %%
features[0: 5]
# Out:
# array([[0.43575046, 0.75433463, 0.67869849],
#        [0.4289907 , 0.75642374, 0.66829862],
#        [0.42743822, 0.76454791, 0.65735138],
#        [0.42726572, 0.76007708, 0.64558309],
#        [0.42605824, 0.75053839, 0.63408849]])

# %%
features_test = scalerFeature.fit_transform(test_df)
features_test[0: 5]
# Out:
# array([[0.66085234, 0.28158683, 0.15101456],
#        [0.62004204, 0.29275238, 0.17756657],
#        [0.59192828, 0.30299046, 0.19748058],
#        [0.5717264 , 0.31443885, 0.20743758],
#        [0.55390122, 0.31642229, 0.22540922]])

# %% [markdown]
# We have converted the datafram to an array which is scaled. I will check if this is a list or not. I have to pass list to the model. So I will convert the numpy array to list.

# %%
np.shape(features), type(features)
# Out:
# ((3051, 3), numpy.ndarray)

# %%
np.shape(features_test), type(features_test)
# Out:
# ((1293, 3), numpy.ndarray)

# %%
features = features.tolist()
features_test = features_test.tolist()
features[0: 5], features_test[0: 5]
# Out:
# ([[0.43575045625837183, 0.7543346289053481, 0.6786984947544472],
#   [0.42899070101064896, 0.7564237403075493, 0.6682986163904515],
#   [0.42743822140135157, 0.7645479113098135, 0.6573513760072981],
#   [0.4272657236669851, 0.7600770768106391, 0.6455830925954082],
#   [0.4260582394523902, 0.7505383890164399, 0.6340884901930971]],
#  [[0.6608523427483415, 0.2815868291724537, 0.15101455834653388],
#   [0.6200420443494035, 0.29275237999924597, 0.1775665686052652],
#   [0.5919282826163643, 0.3029904592840966, 0.19748057629931348],
#   [0.5717264026050421, 0.3144388457192653, 0.20743758014633795],
#   [0.55390121503671, 0.3164222851157046, 0.2254092177717435]])

# %%
type(features), type(features_test)
# Out:
# (list, list)

# %% [markdown]
# We can see that the number of rows are matching the train_df dataframe and the type has changed to List. We are done with features of training and testing data set.

# %% [markdown]
# ### Target

# %% [markdown]
# Now, we will create the target list.

# %%
scalerTarget = MinMaxScaler()

# %%
target = scalerTarget.fit_transform(train_df.iloc[:, 0].values.reshape(-1, 1))

# %%
target
# Out:
# array([[0.43575046],
#        [0.4289907 ],
#        [0.42743822],
#        ...,
#        [0.07652263],
#        [0.07662957],
#        [0.07662957]])

# %%
target_test = scalerTarget.fit_transform(test_df.iloc[:, 0].values.reshape(-1, 1))
target_test
# Out:
# array([[0.66085234],
#        [0.62004204],
#        [0.59192828],
#        ...,
#        [0.76639622],
#        [0.75373095],
#        [0.74247294]])

# %%
target[: 5], target[-5:]
# Out:
# (array([[0.43575046],
#         [0.4289907 ],
#         [0.42743822],
#         [0.42726572],
#         [0.42605824]]),
#  array([[0.07138987],
#         [0.07481171],
#         [0.07652263],
#         [0.07662957],
#         [0.07662957]]))

# %%
np.shape(target), type(target)
# Out:
# ((3051, 1), numpy.ndarray)

# %%
np.shape(target_test), type(target_test)
# Out:
# ((1293, 1), numpy.ndarray)

# %% [markdown]
# Again, I will convert the numpyt array to list

# %%
target = target.tolist()
target_test = target_test.tolist()
type(target), type(target_test)
# Out:
# (list, list)

# %% [markdown]
# ## **TimeSeriesGenerator**

# %%
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.12.0

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# []

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
train_generator = TimeseriesGenerator(features, target, length= 12, sampling_rate= 1, batch_size= 64)
test_generator = TimeseriesGenerator(features_test, target_test, length= 12, sampling_rate= 1, batch_size= 1)

# %%
train_generator[0][0][0]
# Out:
# array([[0.43575046, 0.75433463, 0.67869849],
#        [0.4289907 , 0.75642374, 0.66829862],
#        [0.42743822, 0.76454791, 0.65735138],
#        [0.42726572, 0.76007708, 0.64558309],
#        [0.42605824, 0.75053839, 0.63408849],
#        [0.42605824, 0.75356443, 0.62861487],
#        [0.42605824, 0.73847428, 0.68280371],
#        [0.42605824, 0.72584355, 0.80103391],
#        [0.42605824, 0.71585097, 0.85649992],
592080397], [0.5949155592080397], [0.5949155592080397], [0.5949155592080397], [0.5949155592080397], [0.5949155592080397], [0.5949155592080397], [0.5949155592080397], [0.5949155592080397], [0.5942215253288988], [0.5902886666804331], [0.5784900907350362], [0.5701616841853443], [0.562990000767554], [0.5567436958552852], [0.5507287355693965], [0.5472585661736915], [0.5430943628988456], [0.5405495720086619], [0.537773436492098], [0.5361540241074356], [0.5326838547117306], [0.5299077191951667], [0.5264375497994617], [0.5259748605467011], [0.5227360357773764], [0.5227360357773764], [0.5215793126454747], [0.5197285556344321], [0.5157956969859665], [0.5130195614694025], [0.5116314937111205], [0.5102434259528386], [0.5072359458098942], [0.5058478780516122], [0.5026090532822876], [0.5014523301503859], [0.49867619463382196], [0.49751947150192033], [0.4935866128534546], [0.4926612343479333], [0.4887283756994677], [0.48687761868842505], [0.4845641724246217], [0.48248207078719874], [0.4778551782595921], [0.4741536642375068], [0.4695267717099002], [0.46721332544609684], [0.4607356759074476], [0.41881333431288115], [0.412258420184868], [0.4101884472984412], [0.4094984563609757], [0.40811847441201443], [0.40673849246305305], [0.40639349699432037], [0.40328853762766503], [0.3996660851319407], [0.39569863709345354], [0.39190368678933274], [0.3910411980434705], [0.39017870937163857], [0.3893162206257764], [0.38707375000498323], [0.38345129743522877], [0.3756888990926206], [0.3706864646479352], [0.36947898043334015], [0.36947898043334015], [0.36947898043334015], [0.36947898043334015], [0.36947898043334015], [0.36827149629277556], [0.36533903466048656], [0.3651665369261202], [0.3627515685709606], [0.3601641024814347], [0.3598191069386716], [0.3598191069386716], [0.3598191069386716], [0.3598191069386716], [0.3601641024814347], [0.36602902559795203], [0.37327393073746107], [0.3810363290800691], [0.3855212703216555], [0.38828123421957816], [0.3898337139029058], [0.3944911528788586], [0.40139106247560463], [0.40259854669019945], [0.40173605801836765], [0.4012185647412382], [0.40139106247560463], [0.4027710444245658], [0.40449602184225986], [0.40639349699432037], [0.4101884472984412], [0.41346590439946296], [0.41691585916082075], [0.4219182936795366], [0.423298275628498], [0.426403234921123], [0.43297432074180786], [0.4433848289289227], [0.44847441070929006], [0.4500938230939524], [0.45240726935775566], [0.45240726935775566], [0.45240726935775566], [0.4531013032368967], [0.4542580263687983], [0.4542580263687983], [0.45587743875346065], [0.45610878337984095], [0.45610878337984095], [0.45610878337984095], [0.45610878337984095], [0.4561 ...

# %% [markdown]
# I will store the dictionary in a dataframe

# %%
train_generator_df = pd.DataFrame(list(diction.items()), columns= ["Keys", "Values"])
train_generator_df
# Out:
#             Keys                                             Values
# 0           data  [[0.43575045625837183, 0.7543346289053481, 0.6...
# 1        targets  [[0.43575045625837183], [0.42899070101064896],...
# 2         length                                                 12
# 3  sampling_rate                                                  1
# 4         stride                                                  1
# 5    start_index                                                 12
# 6      end_index                                               3050
# 7        shuffle                                              False
# 8        reverse                                              False
# 9     batch_size                                                 64

# %% [markdown]
# We pass different types of parameters to the model, like feautures, target variable and now we also want our model to use the windowing. So the parameters of windowing like the sampling rate, the length of a window, the stride and all we have to pass to the model. This is done by the object of TimeseriesGenerator. When we see the configuration of it, we see a dictionary. The parameters which we want to pass to the model are the "keys" of the dictionary and the parameter values which we actually pass to the model is the "value" of that particular parameter (i.e. "key"). We can see that above.


# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %% [markdown]
# ### MAE

# %%
model_mae=Sequential()
model_mae.add(LSTM(100,activation='relu',input_shape=(12, 3),return_sequences=True))
model_mae.add(LSTM(100,activation='relu',return_sequences=True))
model_mae.add(LSTM(10,activation='relu'))
model_mae.add(Dense(1))

# %%
model_mae.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),loss='mae', metrics= ["accuracy"])
model_mae.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 12, 100)           41600
#
#  lstm_1 (LSTM)               (None, 12, 100)           80400
#
#  lstm_2 (LSTM)               (None, 10)                4440
#
#  dense (Dense)               (None, 1)                 11
#
# =================================================================
# Total params: 126,451
# Trainable params: 126,451
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model_mae.fit(train_generator, validation_data= test_generator, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 48/48 [==============================] - 13s 183ms/step - loss: 0.0756 - accuracy: 0.0053 - val_loss: 0.2028 - val_accuracy: 0.0031
# Epoch 2/100
# 48/48 [==============================] - 7s 157ms/step - loss: 0.0400 - accuracy: 0.0056 - val_loss: 0.1434 - val_accuracy: 0.0031
# Epoch 3/100
# 48/48 [==============================] - 7s 158ms/step - loss: 0.0395 - accuracy: 0.0053 - val_loss: 0.0610 - val_accuracy: 0.0039
# Epoch 4/100
# 48/48 [==============================] - 9s 182ms/step - loss: 0.0213 - accuracy: 0.0056 - val_loss: 0.0658 - val_accuracy: 0.0039
# Epoch 5/100
# 48/48 [==============================] - 13s 266ms/step - loss: 0.0170 - accuracy: 0.0056 - val_loss: 0.0829 - val_accuracy: 0.0039
# Epoch 6/100
# 48/48 [==============================] - 7s 157ms/step - loss: 0.0284 - accuracy: 0.0056 - val_loss: 0.1181 - val_accuracy: 0.0031
# Epoch 7/100
# 48/48 [==============================] - 9s 181ms/step - loss: 0.0289 - accuracy: 0.0056 - val_loss: 0.1049 - val_accuracy: 0.0039
# Epoch 8/100
# 48/48 [==============================] - 9s 192ms/step - loss: 0.0222 - accuracy: 0.0056 - val_loss: 0.0574 - val_accuracy: 0.0039
# Epoch 9/100
# 48/48 [==============================] - 7s 150ms/step - loss: 0.0224 - accuracy: 0.0056 - val_loss: 0.0556 - val_accuracy: 0.0039
# Epoch 10/100
# 48/48 [==============================] - 9s 187ms/step - loss: 0.0186 - accuracy: 0.0056 - val_loss: 0.1048 - val_accuracy: 0.0039
# Epoch 11/100
# 48/48 [==============================] - 8s 170ms/step - loss: 0.0274 - accuracy: 0.0056 - val_loss: 0.0621 - val_accuracy: 0.0039
# Epoch 12/100
# 48/48 [==============================] - 7s 158ms/step - loss: 0.0248 - accuracy: 0.0056 - val_loss: 0.1163 - val_accuracy: 0.0031
# Epoch 13/100
# 48/48 [==============================] - 8s 165ms/step - loss: 0.0270 - accuracy: 0.0056 - val_loss: 0.0539 - val_accuracy: 0.0039
# Epoch 14/100
# Epoch 93/100
# 48/48 [==============================] - 7s 158ms/step - loss: 0.0157 - accuracy: 0.0056 - val_loss: 0.0402 - val_accuracy: 0.0039
# Epoch 94/100
# 48/48 [==============================] - 8s 172ms/step - loss: 0.0143 - accuracy: 0.0056 - val_loss: 0.0528 - val_accuracy: 0.0039
# Epoch 95/100
# 48/48 [==============================] - 13s 267ms/step - loss: 0.0131 - accuracy: 0.0056 - val_loss: 0.0541 - val_accuracy: 0.0039
# Epoch 96/100
# 48/48 [==============================] - 13s 268ms/step - loss: 0.0103 - accuracy: 0.0056 - val_loss: 0.0402 - val_accuracy: 0.0039
# Epoch 97/100
# 48/48 [==============================] - 7s 146ms/step - loss: 0.0125 - accuracy: 0.0056 - val_loss: 0.0512 - val_accuracy: 0.0039
# Epoch 98/100
# 48/48 [==============================] - 8s 167ms/step - loss: 0.0110 - accuracy: 0.0056 - val_loss: 0.0459 - val_accuracy: 0.0039
# Epoch 99/100
# 48/48 [==============================] - 8s 169ms/step - loss: 0.0107 - accuracy: 0.0056 - val_loss: 0.0397 - val_accuracy: 0.0039
# Epoch 100/100
# 48/48 [==============================] - 13s 266ms/step - loss: 0.0098 - accuracy: 0.0056 - val_loss: 0.0413 - val_accuracy: 0.0039

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ### MSE

# %%
model_mse=Sequential()
model_mse.add(LSTM(100,activation='relu',input_shape=(12, 3),return_sequences=True))
model_mse.add(LSTM(100,activation='relu',return_sequences=True))
model_mse.add(LSTM(10,activation='relu'))
model_mse.add(Dense(1))

# %%
model_mse.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),loss='mse', metrics= ["accuracy"])
model_mse.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 12, 100)           41600
#
#  lstm_4 (LSTM)               (None, 12, 100)           80400
#
#  lstm_5 (LSTM)               (None, 10)                4440
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 126,451
# Trainable params: 126,451
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_mse = model_mse.fit(train_generator, validation_data= test_generator, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 48/48 [==============================] - 13s 186ms/step - loss: 0.0334 - accuracy: 0.0056 - val_loss: 0.0500 - val_accuracy: 0.0031
# Epoch 2/100
# 48/48 [==============================] - 13s 265ms/step - loss: 0.0089 - accuracy: 0.0056 - val_loss: 0.0150 - val_accuracy: 0.0039
# Epoch 3/100
# 48/48 [==============================] - 7s 157ms/step - loss: 0.0109 - accuracy: 0.0056 - val_loss: 0.0237 - val_accuracy: 0.0031
# Epoch 4/100
# 48/48 [==============================] - 8s 168ms/step - loss: 0.0158 - accuracy: 0.0056 - val_loss: 0.1056 - val_accuracy: 0.0031
# Epoch 5/100
# 48/48 [==============================] - 8s 170ms/step - loss: 0.0097 - accuracy: 0.0056 - val_loss: 0.0146 - val_accuracy: 0.0039
# Epoch 6/100
# 48/48 [==============================] - 8s 159ms/step - loss: 0.0049 - accuracy: 0.0056 - val_loss: 0.0183 - val_accuracy: 0.0031
# Epoch 7/100
# 48/48 [==============================] - 9s 182ms/step - loss: 0.0032 - accuracy: 0.0056 - val_loss: 0.0073 - val_accuracy: 0.0039
# Epoch 8/100
# 48/48 [==============================] - 13s 268ms/step - loss: 0.0011 - accuracy: 0.0056 - val_loss: 0.0073 - val_accuracy: 0.0039
# Epoch 9/100
# Epoch 86/100
# 48/48 [==============================] - 8s 158ms/step - loss: 6.8009e-04 - accuracy: 0.0056 - val_loss: 0.0104 - val_accuracy: 0.0039
# Epoch 87/100
# 48/48 [==============================] - 13s 273ms/step - loss: 6.9489e-04 - accuracy: 0.0056 - val_loss: 0.0068 - val_accuracy: 0.0039
# Epoch 88/100
# 48/48 [==============================] - 13s 274ms/step - loss: 6.2329e-04 - accuracy: 0.0056 - val_loss: 0.0082 - val_accuracy: 0.0039
# Epoch 89/100
# 48/48 [==============================] - 13s 273ms/step - loss: 6.3584e-04 - accuracy: 0.0056 - val_loss: 0.0042 - val_accuracy: 0.0039
# Epoch 90/100
# 48/48 [==============================] - 13s 267ms/step - loss: 6.5042e-04 - accuracy: 0.0056 - val_loss: 0.0107 - val_accuracy: 0.0039
# Epoch 91/100
# 48/48 [==============================] - 7s 150ms/step - loss: 7.3068e-04 - accuracy: 0.0056 - val_loss: 0.0041 - val_accuracy: 0.0039
# Epoch 92/100
# 48/48 [==============================] - 8s 173ms/step - loss: 0.0012 - accuracy: 0.0056 - val_loss: 0.0091 - val_accuracy: 0.0039
# Epoch 93/100
# 48/48 [==============================] - 8s 167ms/step - loss: 9.5350e-04 - accuracy: 0.0056 - val_loss: 0.0089 - val_accuracy: 0.0039
# Epoch 94/100
# 48/48 [==============================] - 7s 146ms/step - loss: 6.0882e-04 - accuracy: 0.0056 - val_loss: 0.0047 - val_accuracy: 0.0039
# Epoch 95/100
# 48/48 [==============================] - 8s 175ms/step - loss: 4.2479e-04 - accuracy: 0.0056 - val_loss: 0.0052 - val_accuracy: 0.0039
# Epoch 96/100
# 48/48 [==============================] - 13s 267ms/step - loss: 5.6163e-04 - accuracy: 0.0056 - val_loss: 0.0063 - val_accuracy: 0.0039
# Epoch 97/100
# 48/48 [==============================] - 7s 149ms/step - loss: 5.6352e-04 - accuracy: 0.0056 - val_loss: 0.0046 - val_accuracy: 0.0039
# Epoch 98/100
# 48/48 [==============================] - 8s 168ms/step - loss: 6.2451e-04 - accuracy: 0.0056 - val_loss: 0.0044 - val_accuracy: 0.0039
# Epoch 99/100
# 48/48 [==============================] - 13s 266ms/step - loss: 0.0018 - accuracy: 0.0056 - val_loss: 0.0067 - val_accuracy: 0.0039
# Epoch 100/100
# 48/48 [==============================] - 7s 149ms/step - loss: 6.6167e-04 - accuracy: 0.0056 - val_loss: 0.0039 - val_accuracy: 0.0039

# %%
plt.plot(history_mse.history['accuracy'])
plt.plot(history_mse.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history_mse.history['loss'])
plt.plot(history_mse.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # Winter

# %% [markdown]
# ## **Importing Data**

# %%
river_2018_w = pd.read_csv("RiverFlow2022Winter.csv")

# %%
river_2018_w
# Out:
#                 Timestamp  BlairCreek  Bridgeport  BridgeportWQ       Doon  \
# 0     2022-10-01 00:00:00    0.171187   12.149875     11.828061  10.794518
# 1     2022-10-01 01:00:00    0.171813   12.077000     11.794388  10.765386
# 2     2022-10-01 02:00:00    0.171813   12.030625     11.755102  10.791114
# 3     2022-10-01 03:00:00    0.170875   12.024000     11.760714  10.794915
# 4     2022-10-01 04:00:00    0.171187   12.024000     11.800000  10.792856
# ...                   ...         ...         ...           ...        ...
# 2227  2023-01-01 19:00:00    6.112500   63.906250     66.752000  69.145801
# 2228  2023-01-01 20:00:00    6.677500   62.625000     65.328000  67.147994
# 2229  2023-01-01 21:00:00    6.511250   61.468750     63.942500  66.370603
# 2230  2023-01-01 22:00:00    6.135000   60.479167     62.864375  64.925872
# 2231  2023-01-01 23:00:00    5.809821   61.052083     64.304000  63.314200
#
#         Drayton  Elmira  Erbsville     Keldon    Leggatt  MillCreek  \
# 0      0.371786  0.3600   0.063019   0.103283   0.498000   0.262035
# 1      0.369183  0.3600   0.063339   0.102255   0.498000   0.261908
# 2      0.367623  0.3600   0.062500   0.101386   0.495527   0.261070
# 3      0.367192  0.3600   0.062500   0.100832   0.496367   0.260097
# 4      0.364427  0.3600   0.061941   0.098935   0.500940   0.258969
# ...         ...     ...        ...        ...        ...        ...
# 2227  44.066383  3.1520   0.462402  11.259375  27.373467   2.099606
# 2228  42.725918  3.1205   0.433461  10.779167  26.982467   2.065631
# 2229  41.430100  3.0890   0.410553  10.689583  26.656740   2.033860
# 2230  40.200860  3.0575   0.390549  10.392708  26.371090   2.002358
# 2231  39.090276  3.0365   0.370860   9.792708  26.052380   1.969343
#
#       Moorefield  Phillipsburg    Road32  VictoriaRoad   Waldemar  \
# 0       0.045727      0.291000  2.351468      1.079476   0.759601
# 1       0.047165      0.286750  2.337997      1.085459   0.758880
# 2       0.047909      0.285250  2.326976      1.090000   0.760562
# 3       0.048493      0.283250  2.303709      1.090000   0.766330
# 4       0.048725      0.281250  2.277067      1.090000   0.767120
# ...          ...           ...       ...           ...        ...
# 2227   13.084098     61.677028  6.587513      0.456600  26.698283
# 2228   12.854528     58.653723  6.661228      0.456600  26.765158
# 2229   12.601612     55.564362  6.686446      0.456600  26.984320
# 2230   12.344837     52.334574  6.670927      0.456600  27.173024
# 2231   12.095341     49.293694  6.667047      0.456600  27.610024
#
#       WillowBrook       York
# 0        0.027230  21.834511
# 1        0.027190  21.981250
# 2        0.026947  22.079076
# 3        0.026827  22.091304
# 4        0.026800  22.091304
# ...           ...        ...
# 2227     1.973442  70.339806
# 2228     2.023615  77.500000
# 2229     2.150197  86.687500
# 2230     2.248953  90.843750
# 2231     2.328807  97.281250
#
# [2232 rows x 18 columns]

# %%
river_2018_w.set_index(["Timestamp"], inplace= True)

# %%
river_2018_w[river_2018_w == np.nan].count()
# Out:
# BlairCreek      0
# Bridgeport      0
# BridgeportWQ    0
# Doon            0
# Drayton         0
# Elmira          0
# Erbsville       0
# Keldon          0
# Leggatt         0
# MillCreek       0
# Moorefield      0
# Phillipsburg    0
# Road32          0
# VictoriaRoad    0
# Waldemar        0
# WillowBrook     0
# York            0
# dtype: int64

# %%
river_2018_w[river_2018_w <= 0].count()
# Out:
# BlairCreek      0
# Bridgeport      0
# BridgeportWQ    0
# Doon            0
# Drayton         0
# Elmira          0
# Erbsville       0
# Keldon          0
# Leggatt         0
# MillCreek       0
# Moorefield      0
# Phillipsburg    0
# Road32          0
# VictoriaRoad    0
# Waldemar        0
# WillowBrook     0
# York            0
# dtype: int64

# %% [markdown]
# ## **Preprocessing of DataFrame**

# %% [markdown]
# We need only York, Doon and Bridgeport Stations data

# %% [markdown]
# Extracting only the three stations we which we need

# %%
river_2018_w = river_2018_w[["York", "Doon", "Bridgeport"]]
river_2018_w
# Out:
#                           York       Doon  Bridgeport
# Timestamp
# 2022-10-01 00:00:00  21.834511  10.794518   12.149875
# 2022-10-01 01:00:00  21.981250  10.765386   12.077000
# 2022-10-01 02:00:00  22.079076  10.791114   12.030625
# 2022-10-01 03:00:00  22.091304  10.794915   12.024000
# 2022-10-01 04:00:00  22.091304  10.792856   12.024000
# ...                        ...        ...         ...
# 2023-01-01 19:00:00  70.339806  69.145801   63.906250
# 2023-01-01 20:00:00  77.500000  67.147994   62.625000
# 2023-01-01 21:00:00  86.687500  66.370603   61.468750
# 2023-01-01 22:00:00  90.843750  64.925872   60.479167
# 2023-01-01 23:00:00  97.281250  63.314200   61.052083
#
# [2232 rows x 3 columns]

# %%
len(river_2018_w)
# Out:
# 2232

# %% [markdown]
# Here, I will divide the dataframe into training and testing by 70-30 split in chronological order. So training would contain - 3075 and testing would contain the rest.

# %%
train_2018_w = river_2018_w.iloc[0: 3075, :]
train_2018_w
# Out:
#                           York       Doon  Bridgeport
# Timestamp
# 2022-10-01 00:00:00  21.834511  10.794518   12.149875
# 2022-10-01 01:00:00  21.981250  10.765386   12.077000
# 2022-10-01 02:00:00  22.079076  10.791114   12.030625
# 2022-10-01 03:00:00  22.091304  10.794915   12.024000
# 2022-10-01 04:00:00  22.091304  10.792856   12.024000
# ...                        ...        ...         ...
# 2023-01-01 19:00:00  70.339806  69.145801   63.906250
# 2023-01-01 20:00:00  77.500000  67.147994   62.625000
# 2023-01-01 21:00:00  86.687500  66.370603   61.468750
# 2023-01-01 22:00:00  90.843750  64.925872   60.479167
# 2023-01-01 23:00:00  97.281250  63.314200   61.052083
#
# [2232 rows x 3 columns]

# %%
test_2018_w = river_2018_w.iloc[3075: , :]
test_2018_w
# Out:
# Empty DataFrame
# Columns: [York, Doon, Bridgeport]
# Index: []

# %% [markdown]
# Now, we need to use windowing.

# %%
train_df_w = pd.concat([train_2018_w["York"], train_2018_w["Doon"].shift(-18), train_2018_w["Bridgeport"].shift(-24)], axis= 1)
train_df_w
# Out:
#                           York       Doon  Bridgeport
# Timestamp
# 2022-10-01 00:00:00  21.834511  10.589151   12.043875
# 2022-10-01 01:00:00  21.981250  10.597307   11.964375
# 2022-10-01 02:00:00  22.079076  10.665629   11.984250
# 2022-10-01 03:00:00  22.091304  10.719387   11.937875
# 2022-10-01 04:00:00  22.091304  10.733321   11.918000
# ...                        ...        ...         ...
# 2023-01-01 19:00:00  70.339806        NaN         NaN
# 2023-01-01 20:00:00  77.500000        NaN         NaN
# 2023-01-01 21:00:00  86.687500        NaN         NaN
# 2023-01-01 22:00:00  90.843750        NaN         NaN
# 2023-01-01 23:00:00  97.281250        NaN         NaN
#
# [2232 rows x 3 columns]

# %%
# Timestamp
# 2022-12-31 08:00:00  26.561111  62.697758   72.074250
# 2022-12-31 09:00:00  27.008889  63.981248   72.007375
# 2022-12-31 10:00:00  27.543333  68.841947   72.475500
# 2022-12-31 11:00:00  27.991111  69.124285   72.957000
# 2022-12-31 12:00:00  28.352222  65.450897   72.355125
# 2022-12-31 13:00:00  29.031111  65.327831   72.261500
# 2022-12-31 14:00:00  29.666667  65.504631   73.064000
# 2022-12-31 15:00:00  30.244444  66.968910   70.723375
# 2022-12-31 16:00:00  30.851111  69.697991   67.291667
# 2022-12-31 17:00:00  31.487295  71.693782   66.614583
# 2022-12-31 18:00:00  31.909221  72.293820   65.427083
# 2022-12-31 19:00:00  32.432992  72.813497   63.906250
# 2022-12-31 20:00:00  32.782172  72.959208   62.625000
# 2022-12-31 21:00:00  33.422336  72.308833   61.468750
# 2022-12-31 22:00:00  36.143033  71.986607   60.479167
# 2022-12-31 23:00:00  36.434016  72.204155   61.052083
# 2023-01-01 00:00:00  38.005328  71.403865         NaN
# 2023-01-01 01:00:00  37.161475  69.145801         NaN
# 2023-01-01 02:00:00  37.452459  67.147994         NaN
# 2023-01-01 03:00:00  38.567213  66.370603         NaN
# 2023-01-01 04:00:00  40.213934  64.925872         NaN
# 2023-01-01 05:00:00  42.700820  63.314200         NaN
# 2023-01-01 06:00:00  45.624590        NaN         NaN
# 2023-01-01 07:00:00  48.415574        NaN         NaN
# 2023-01-01 08:00:00  51.884016        NaN         NaN
# 2023-01-01 09:00:00  52.760451        NaN         NaN
# 2023-01-01 10:00:00  52.909631        NaN         NaN
# 2023-01-01 11:00:00  53.226639        NaN         NaN
# 2023-01-01 12:00:00  54.476025        NaN         NaN
# 2023-01-01 13:00:00  56.242718        NaN         NaN
# 2023-01-01 14:00:00  56.918447        NaN         NaN
# 2023-01-01 15:00:00  57.477670        NaN         NaN
# 2023-01-01 16:00:00  59.341748        NaN         NaN
# 2023-01-01 17:00:00  62.720388        NaN         NaN
# 2023-01-01 18:00:00  65.586408        NaN         NaN
# 2023-01-01 19:00:00  70.339806        NaN         NaN
# 2023-01-01 20:00:00  77.500000        NaN         NaN
# 2023-01-01 21:00:00  86.687500        NaN         NaN
# 2023-01-01 22:00:00  90.843750        NaN         NaN
# 2023-01-01 23:00:00  97.281250        NaN         NaN

# %% [markdown]
# We can see that there are 18 missing in Doon and 24 missing in Bridgeport. Now we will drop na values, so total number of rows would decrease by 24.

# %%
train_df_w.shape, test_df_w.shape
# Out:
# ((2232, 3), (0, 3))

# %%
train_df_w.dropna(inplace= True)
train_df_w.shape
# Out:
# (2208, 3)

# %%
test_df_w.dropna(inplace= True)
test_df_w.shape
# Out:
# (0, 3)

# %% [markdown]
# We can see that there is a decrease of 24 rows after dropping the na values. So far everything is correct.

# %% [markdown]
# ## **Features and Target extraction with Scaling**

# %%
train_df_w.head()
# Out:
#                           York       Doon  Bridgeport
# Timestamp
# 2022-10-01 00:00:00  21.834511  10.589151   12.043875
# 2022-10-01 01:00:00  21.981250  10.597307   11.964375
# 2022-10-01 02:00:00  22.079076  10.665629   11.984250
# 2022-10-01 03:00:00  22.091304  10.719387   11.937875
# 2022-10-01 04:00:00  22.091304  10.733321   11.918000

# %%
train_df_w.tail()
# Out:
#                           York       Doon  Bridgeport
# Timestamp
# 2022-12-31 19:00:00  32.432992  72.813497   63.906250
# 2022-12-31 20:00:00  32.782172  72.959208   62.625000
# 2022-12-31 21:00:00  33.422336  72.308833   61.468750
# 2022-12-31 22:00:00  36.143033  71.986607   60.479167
# 2022-12-31 23:00:00  36.434016  72.204155   61.052083

# %% [markdown]
# ### Features

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scalerFeature = MinMaxScaler()

# %%
features_w = scalerFeature.fit_transform(train_df_w)

# %%
features_w[0: 5]
# Out:
# array([[0.31222236, 0.08051794, 0.09345971],
#        [0.31913519, 0.08063817, 0.09233461],
#        [0.32374374, 0.08164541, 0.09261588],
#        [0.32431981, 0.08243793, 0.09195957],
#        [0.32431981, 0.08264335, 0.0916783 ]])

# %%
features_test_w = scalerFeature.fit_transform(test_df_w)
features_test_w[0: 5]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-55edd689195c> in <cell line: 1>()
# ----> 1 features_test_w = scalerFeature.fit_transform(test_df_w)
#       2 features_test_w[0: 5]
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     876         if y is None:
#     877             # fit method of arity 1 (unsupervised transformation)
# --> 878             return self.fit(X, **fit_params).transform(X)
#     879         else:
#     880             # fit method of arity 2 (supervised transformation)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_data.py in fit(self, X, y)
#     425         # Reset internal state before fitting
#     426         self._reset()
# --> 427         return self.partial_fit(X, y)
#     428
#     429     def partial_fit(self, X, y=None):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_data.py in partial_fit(self, X, y)
#     464
#     465         first_pass = not hasattr(self, "n_samples_seen_")
# --> 466         X = self._validate_data(
#     467             X,
#     468             reset=first_pass,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     563             raise ValueError("Validation should be done on X, y or both.")
#     564         elif not no_val_X and no_val_y:
# --> 565             X = check_array(X, input_name="X", **check_params)
#     566             out = X
#     567         elif no_val_X and not no_val_y:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     929         n_samples = _num_samples(array)
#     930         if n_samples < ensure_min_samples:
# --> 931             raise ValueError(
#     932                 "Found array with %d sample(s) (shape=%s) while a"
#     933                 " minimum of %d is required%s."
#
# ValueError: Found array with 0 sample(s) (shape=(0, 3)) while a minimum of 1 is required by MinMaxScaler.

# %% [markdown]
# We have converted the datafram to an array which is scaled. I will check if this is a list or not. I have to pass list to the model. So I will convert the numpy array to list.

# %%
np.shape(features_w), type(features_w)

# %%
np.shape(features_test_w), type(features_test_w)

# %%
features_w = features_w.tolist()
features_test_w = features_test_w.tolist()
features_w[0: 5], features_test_w[0: 5]

# %%
type(features_w), type(features_test_w)

# %% [markdown]
# We can see that the number of rows are matching the train_df dataframe and the type has changed to List. We are done with features of training and testing data set.

# %% [markdown]
# ### Target

# %% [markdown]
# Now, we will create the target list.

# %%
scalerTarget = MinMaxScaler()

# %%
target_w = scalerTarget.fit_transform(train_df_w.iloc[:, 0].values.reshape(-1, 1))

# %%
target_w

# %%
target_test_w = scalerTarget.fit_transform(test_df_w.iloc[:, 0].values.reshape(-1, 1))
target_test_w

# %%
target_w[: 5], target_w[-5:]

# %%
np.shape(target_w), type(target_w)

# %%
np.shape(target_test_w), type(target_test_w)

# %% [markdown]
# Again, I will convert the numpyt array to list

# %%
target_w = target_w.tolist()
target_test_w = target_test_w.tolist()
type(target_w), type(target_test_w)

# %% [markdown]
# ## **TimeSeriesGenerator**

# %%
import tensorflow as tf

# %%
print(tf.__version__)

# %%
print(tf.config.list_physical_devices('GPU'))

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
train_generator_w = TimeseriesGenerator(features_w, target_w, length= 12, sampling_rate= 1, batch_size= 64)
test_generator_w = TimeseriesGenerator(features_test_w, target_test_w, length= 12, sampling_rate= 1, batch_size= 1)

# %%
train_generator_w[0][0][0]

# %%
train_generator_w.get_config()

# %% [markdown]
# The configuration shows a dictionary. I will try to get more information about the dictionary.

# %%
diction_w = train_generator_w.get_config()
diction_w.keys()

# %%
diction_w["targets"]

# %% [markdown]
# I will store the dictionary in a dataframe

# %%
train_generator_df_w = pd.DataFrame(list(diction_w.items()), columns= ["Keys", "Values"])
train_generator_df_w

# %% [markdown]
# We pass different types of parameters to the model, like feautures, target variable and now we also want our model to use the windowing. So the parameters of windowing like the sampling rate, the length of a window, the stride and all we have to pass to the model. This is done by the object of TimeseriesGenerator. When we see the configuration of it, we see a dictionary. The parameters which we want to pass to the model are the "keys" of the dictionary and the parameter values which we actually pass to the model is the "value" of that particular parameter (i.e. "key"). We can see that above.
#
# We will do the same with the test data set

# %%
test_generator_w[0][0][0]

# %%
test_generator_w.get_config()

# %%
diction_test_w = test_generator_w.get_config()
diction_test_w.keys()

# %%
diction_test["targets"]

# %% [markdown]
# I will store the dictionary in a dataframe

# %%
test_generator_df_w = pd.DataFrame(list(diction_test_w.items()), columns= ["Keys", "Values"])
test_generator_df_w

# %% [markdown]
# We can see that it is same as the train generator object.

# %% [markdown]
# ## **Building Model**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %% [markdown]
# ### MAE

# %%
model_mae_w=Sequential()
model_mae_w.add(LSTM(100,activation='relu',input_shape=(12, 3),return_sequences=True))
model_mae_w.add(LSTM(100,activation='relu',return_sequences=True))
model_mae_w.add(LSTM(10,activation='relu'))
model_mae_w.add(Dense(1))

# %%
model_mae_w.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),loss='mae', metrics= ["accuracy"])
model_mae_w.summary()

# %%
history = model_mae_w.fit(train_generator_w, validation_data= test_generator_w, epochs=100, verbose=1)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ### MSE

# %%
model_mse_w=Sequential()
model_mse_w.add(LSTM(100,activation='relu',input_shape=(12, 3),return_sequences=True))
model_mse_w.add(LSTM(100,activation='relu',return_sequences=True))
model_mse_w.add(LSTM(10,activation='relu'))
model_mse_w.add(Dense(1))

# %%
model_mse_w.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),loss='mse', metrics= ["accuracy"])
model_mse_w.summary()

# %%
history_mse = model_mse_w.fit(train_generator_w, validation_data= test_generator_w, epochs=100, verbose=1)

# %%
plt.plot(history_mse.history['accuracy'])
plt.plot(history_mse.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history_mse.history['loss'])
plt.plot(history_mse.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
